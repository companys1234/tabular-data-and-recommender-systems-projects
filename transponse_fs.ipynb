# %%
import numpy as np
def transponse(m):
  i,j = m.shape
  mat = np.zeros((j,i))
  for z in range(len(zeros_matrix)):
    for u in range((z)):
      print(z,u)
      mat[u][z] = mat[z][u]
  return mat

# %%
zeros_matrix = np.zeros((1, 2))
print(zeros_matrix)
# Out:
# [[0. 0.]]

# %%
transponse(zeros_matrix)
# Out:
# array([[0.],
#        [0.]])
