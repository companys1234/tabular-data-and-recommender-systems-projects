# %% [markdown]
# f(x) = x
#
#
#
#
# ![Снимок экрана 2025-02-12 192729.png](data:image/png;base64,...)

# %%
import math
a = 3
x = [0,1,2,3,4]
y = [0,1,2,3,4]
f1 = y[a]
f2 = (y[a+1] - y[a])/(x[a+1] - x[a])
f3 = (f2 - f2)/(x[a+1] - x[a])
taylor = f1 + (f2*(x[a]-a)) + (f3/math.factorial(2))*((x[a]-a)^2)
print(taylor)
# Out:
# 3.0

# %% [markdown]
# f(x)=X^2

# %%
import math
a = 0
x = [0,1,2,3,4]
y = [0,1,4,9,16]
f1 = y[a]
f2 = (y[a+1] - y[a])/(x[a+1] - x[a])
f3 = (f2 - f2)/(x[a+1] - x[a])
taylor = f1 + (f2*(x[a]-a)) + (f3/math.factorial(2))*((x[a]-a)^2)
print(taylor)
# Out:
# 0.0
